# %%
import pandas as pd

# %%
pl_past=pd.read_excel('d:/python_for_prepare/project/epl_data4.xlsx')
pl_20=pd.read_excel('D:/python_for_prepare/project/epl_test6.xlsx')

# %%
pl_past.drop('Unnamed: 0',axis=1,inplace=True)
pl_past
# Out:
#          시즌         날짜                    홈팀                  어웨이팀 경기결과  \
# 0     10/11 2010-08-14           Aston Villa       West Ham United    H
# 1     10/11 2010-08-14      Blackburn Rovers               Everton    H
# 2     10/11 2010-08-14      Bolton Wanderers                Fulham    D
# 3     10/11 2010-08-14               Chelsea  West Bromwich Albion    H
# 4     10/11 2010-08-14            Sunderland       Birmingham City    D
# ...     ...        ...                   ...                   ...  ...
# 4067  20/21 2021-03-06               Burnley               Arsenal    D
# 4068  20/21 2021-03-06      Sheffield United           Southampton    A
# 4069  20/21 2021-03-07             Liverpool                Fulham    A
# 4070  20/21 2021-03-07       Manchester City     Manchester United    A
# 4071  20/21 2021-03-07  West Bromwich Albion      Newcastle United    D
#
#       홈팀 풀타임 득점  어웨이팀 풀타임 득점 하프타임 결과  홈팀 하프타임 득점  어웨이팀 하프타임 득점  ...  홈팀 태클  \
# ...

# %%
pl_20.drop('Unnamed: 0',axis=1,inplace=True)
pl_20
# Out:
#         시즌         날짜                       홈팀               어웨이팀 경기결과  \
# 0    20/21 2021-03-07        Tottenham Hotspur     Crystal Palace    H
# 1    20/21 2021-03-08                  Chelsea            Everton    H
# 2    20/21 2021-03-08          West Ham United       Leeds United    H
# 3    20/21 2021-03-10          Manchester City        Southampton    H
# 4    20/21 2021-03-12         Newcastle United        Aston Villa    D
# ..     ...        ...                      ...                ...  ...
# 103  20/21 2021-05-23                Liverpool     Crystal Palace    H
# 104  20/21 2021-05-23          Manchester City            Everton    H
# 105  20/21 2021-05-23         Sheffield United            Burnley    H
# 106  20/21 2021-05-23          West Ham United        Southampton    H
# 107  20/21 2021-05-23  Wolverhampton Wanderers  Manchester United    A
#
#      홈팀 풀타임 득점  어웨이팀 풀타임 득점 하프타임 결과  홈팀 하프타임 득점  어웨이팀 하프타임 득점  ...  홈팀 태클  \
# ...

# %%
pl_df=pd.concat([pl_past,pl_20])
pl_df
# Out:
#         시즌         날짜                       홈팀                  어웨이팀 경기결과  \
# 0    10/11 2010-08-14              Aston Villa       West Ham United    H
# 1    10/11 2010-08-14         Blackburn Rovers               Everton    H
# 2    10/11 2010-08-14         Bolton Wanderers                Fulham    D
# 3    10/11 2010-08-14                  Chelsea  West Bromwich Albion    H
# 4    10/11 2010-08-14               Sunderland       Birmingham City    D
# ..     ...        ...                      ...                   ...  ...
# 103  20/21 2021-05-23                Liverpool        Crystal Palace    H
# 104  20/21 2021-05-23          Manchester City               Everton    H
# 105  20/21 2021-05-23         Sheffield United               Burnley    H
# 106  20/21 2021-05-23          West Ham United           Southampton    H
# 107  20/21 2021-05-23  Wolverhampton Wanderers     Manchester United    A
#
#      홈팀 풀타임 득점  어웨이팀 풀타임 득점 하프타임 결과  홈팀 하프타임 득점  어웨이팀 하프타임 득점  ...  홈팀 태클  \
# ...

# %%
pl_15=pl_df[pl_df['시즌']=='15/16']
pl_16=pl_df[pl_df['시즌']=='16/17']
pl_17=pl_df[pl_df['시즌']=='17/18']
pl_18=pl_df[pl_df['시즌']=='18/19']
pl_19=pl_df[pl_df['시즌']=='19/20']
pl_20=pl_df[pl_df['시즌']=='20/21']
pl_half=pd.concat([pl_15,pl_16,pl_17,pl_18,pl_19,pl_20])
pl_tot_h=pl_half[pl_half['홈팀']=='Tottenham Hotspur']
pl_tot_a=pl_half[pl_half['어웨이팀']=='Tottenham Hotspur']

# %%
pl_tot_h.keys()
# Out:
# Index(['시즌', '날짜', '홈팀', '어웨이팀', '경기결과', '홈팀 풀타임 득점', '어웨이팀 풀타임 득점', '하프타임 결과',
#        '홈팀 하프타임 득점', '어웨이팀 하프타임 득점', '하프타임 득점 차', '홈팀 점유율', '홈팀 패스', '홈팀 터치',
#        '홈팀 슈팅', '홈팀 유효슈팅', '어웨이팀 점유율', '어웨이팀 패스', '어웨이팀 터치', '어웨이팀 슈팅',
#        '어웨이팀 유효슈팅', '홈팀 코너킥', '어웨이팀 코너킥', '홈팀 태클', '어웨이팀 태클', '홈팀 오프사이드',
#        '어웨이팀 오프사이드', '홈팀 파울', '홈팀 엘로카드', '홈팀 레드카드', '어웨이팀 파울', '어웨이팀 엘로카드',
#        '어웨이팀 레드카드'],
#       dtype='object')

# %%
pl_tot_h.drop(['하프타임 결과','홈팀 하프타임 득점','어웨이팀 하프타임 득점',
       '어웨이팀 점유율', '어웨이팀 패스', '어웨이팀 터치', '어웨이팀 슈팅',
       '어웨이팀 유효슈팅','어웨이팀 코너킥' ,'어웨이팀 태클',
       '어웨이팀 오프사이드', '어웨이팀 파울', '어웨이팀 엘로카드',
       '어웨이팀 레드카드'],axis=1,inplace=True)
pl_tot_h.rename(columns={'홈팀 풀타임 득점':'득점','어웨이팀 풀타임 득점':'실점','홈팀 점유율':'점유율', '홈팀 패스':'패스', '홈팀 터치':'터치', '홈팀 슈팅':'슈팅',
       '홈팀 유효슈팅':'유효슈팅', '홈팀 코너킥':'코너킥', '홈팀 태클':'태클', '홈팀 오프사이드':'오프사이드', '홈팀 파울':'파울', '홈팀 엘로카드':'엘로카드',
       '홈팀 레드카드':'레드카드'},inplace=True)
pl_tot_h.set_index('날짜',inplace=True)
pl_tot_h
# Out:
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                시즌                 홈팀                     어웨이팀 경기결과  득점  실점  \
# 날짜
# 2015-08-15  15/16  Tottenham Hotspur               Stoke City    D   2   2
# 2015-08-29  15/16  Tottenham Hotspur                  Everton    D   0   0
# 2015-09-20  15/16  Tottenham Hotspur           Crystal Palace    H   1   0
# ...

# %%
pl_tot_a.drop(['하프타임 결과','홈팀 하프타임 득점','어웨이팀 하프타임 득점',
       '홈팀 점유율', '홈팀 패스', '홈팀 터치', '홈팀 슈팅','홈팀 유효슈팅', 
       '홈팀 코너킥', '홈팀 태클', '홈팀 오프사이드', '홈팀 파울', '홈팀 엘로카드', '홈팀 레드카드'],axis=1,inplace=True)
pl_tot_a.rename(columns={'홈팀 풀타임 득점':'실점','어웨이팀 풀타임 득점':'득점','어웨이팀 점유율':'점유율', '어웨이팀 패스':'패스', '어웨이팀 터치':'터치', '어웨이팀 슈팅':'슈팅',
       '어웨이팀 유효슈팅':'유효슈팅', '어웨이팀 코너킥':'코너킥', '어웨이팀 태클':'태클', '어웨이팀 오프사이드':'오프사이드', '어웨이팀 파울':'파울', '어웨이팀 엘로카드':'엘로카드',
       '어웨이팀 레드카드':'레드카드'},inplace=True)
pl_tot_a.set_index('날짜',inplace=True)
pl_tot_a=pl_tot_a[['시즌','홈팀','어웨이팀','경기결과','득점','실점','하프타임 득점 차','점유율','패스','터치','슈팅','유효슈팅','코너킥','태클','오프사이드','파울','엘로카드','레드카드']]
# Out:
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
pl_tot_a
# Out:
#                시즌                 홈팀               어웨이팀 경기결과  득점  실점  \
# 날짜
# 2015-08-08  15/16  Manchester United  Tottenham Hotspur    H   0   1
# 2015-08-22  15/16     Leicester City  Tottenham Hotspur    D   1   1
# 2015-09-13  15/16         Sunderland  Tottenham Hotspur    A   1   0
# 2015-10-04  15/16       Swansea City  Tottenham Hotspur    D   2   2
# 2015-10-25  15/16    AFC Bournemouth  Tottenham Hotspur    A   5   1
# ...           ...                ...                ...  ...  ..  ..
# 2021-03-21  20/21        Aston Villa  Tottenham Hotspur    A   2   0
# 2021-04-04  20/21   Newcastle United  Tottenham Hotspur    D   2   2
# 2021-04-16  20/21            Everton  Tottenham Hotspur    D   2   2
# 2021-05-08  20/21       Leeds United  Tottenham Hotspur    H   1   3
# 2021-05-23  20/21     Leicester City  Tottenham Hotspur    A   4   2
#
#             하프타임 득점 차   점유율   패스   터치  슈팅  유효슈팅  코너킥  태클  오프사이드  파울  엘로카드  \
# 날짜
# ...

# %%
def home(x):
    if x=='H':return 3
    elif x=='D':return 1
    else: return 0
def away(y):
    if y=='A':return 3
    elif y=='D':return 1
    else: return 0

# %%
pl_tot_h['경기결과']=pl_tot_h['경기결과'].apply(home)
pl_tot_a['경기결과']=pl_tot_a['경기결과'].apply(away)
# Out:
# <ipython-input-12-317487a44b48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pl_tot_h['경기결과']=pl_tot_h['경기결과'].apply(home)

# %%
pl_Tot_son=pd.concat([pl_tot_h,pl_tot_a])
pl_Tot_son.sort_index(inplace=True)
pl_Tot_son
# Out:
#                시즌                 홈팀                     어웨이팀  경기결과  득점  실점  \
# 날짜
# 2015-08-08  15/16  Manchester United        Tottenham Hotspur     0   0   1
# 2015-08-15  15/16  Tottenham Hotspur               Stoke City     1   2   2
# 2015-08-22  15/16     Leicester City        Tottenham Hotspur     1   1   1
# 2015-08-29  15/16  Tottenham Hotspur                  Everton     1   0   0
# 2015-09-13  15/16         Sunderland        Tottenham Hotspur     3   1   0
# ...           ...                ...                      ...   ...  ..  ..
# 2021-05-02  20/21  Tottenham Hotspur         Sheffield United     3   4   0
# 2021-05-08  20/21       Leeds United        Tottenham Hotspur     0   1   3
# 2021-05-16  20/21  Tottenham Hotspur  Wolverhampton Wanderers     3   2   0
# 2021-05-19  20/21  Tottenham Hotspur              Aston Villa     0   1   2
# 2021-05-23  20/21     Leicester City        Tottenham Hotspur     3   4   2
#
# ...

# %%
pl_10=pl_df[pl_df['시즌']=='10/11']
pl_11=pl_df[pl_df['시즌']=='11/12']
pl_12=pl_df[pl_df['시즌']=='12/13']
pl_13=pl_df[pl_df['시즌']=='13/14']
pl_14=pl_df[pl_df['시즌']=='14/15']
pl_half=pd.concat([pl_10,pl_11,pl_12,pl_13,pl_14])
pl_tot_h=pl_half[pl_half['홈팀']=='Tottenham Hotspur']
pl_tot_a=pl_half[pl_half['어웨이팀']=='Tottenham Hotspur']

# %%
pl_tot_h.drop(['하프타임 결과','홈팀 하프타임 득점','어웨이팀 하프타임 득점',
       '어웨이팀 점유율', '어웨이팀 패스', '어웨이팀 터치', '어웨이팀 슈팅',
       '어웨이팀 유효슈팅','어웨이팀 코너킥' ,'어웨이팀 태클',
       '어웨이팀 오프사이드', '어웨이팀 파울', '어웨이팀 엘로카드',
       '어웨이팀 레드카드'],axis=1,inplace=True)
pl_tot_h.rename(columns={'홈팀 풀타임 득점':'득점','어웨이팀 풀타임 득점':'실점','홈팀 점유율':'점유율', '홈팀 패스':'패스', '홈팀 터치':'터치', '홈팀 슈팅':'슈팅',
       '홈팀 유효슈팅':'유효슈팅', '홈팀 코너킥':'코너킥', '홈팀 태클':'태클', '홈팀 오프사이드':'오프사이드', '홈팀 파울':'파울', '홈팀 엘로카드':'엘로카드',
       '홈팀 레드카드':'레드카드'},inplace=True)
pl_tot_h.set_index('날짜',inplace=True)
pl_tot_h
# Out:
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                시즌                 홈팀                     어웨이팀 경기결과  득점  실점  \
# 날짜
# 2010-08-14  10/11  Tottenham Hotspur          Manchester City    D   0   0
# 2010-08-28  10/11  Tottenham Hotspur           Wigan Athletic    A   0   1
# 2010-09-18  10/11  Tottenham Hotspur  Wolverhampton Wanderers    H   3   1
# ...

# %%
pl_tot_a.drop(['하프타임 결과','홈팀 하프타임 득점','어웨이팀 하프타임 득점',
       '홈팀 점유율', '홈팀 패스', '홈팀 터치', '홈팀 슈팅','홈팀 유효슈팅', 
       '홈팀 코너킥', '홈팀 태클', '홈팀 오프사이드', '홈팀 파울', '홈팀 엘로카드', '홈팀 레드카드'],axis=1,inplace=True)
pl_tot_a.rename(columns={'홈팀 풀타임 득점':'실점','어웨이팀 풀타임 득점':'득점','어웨이팀 점유율':'점유율', '어웨이팀 패스':'패스', '어웨이팀 터치':'터치', '어웨이팀 슈팅':'슈팅',
       '어웨이팀 유효슈팅':'유효슈팅', '어웨이팀 코너킥':'코너킥', '어웨이팀 태클':'태클', '어웨이팀 오프사이드':'오프사이드', '어웨이팀 파울':'파울', '어웨이팀 엘로카드':'엘로카드',
       '어웨이팀 레드카드':'레드카드'},inplace=True)
pl_tot_a.set_index('날짜',inplace=True)
pl_tot_a=pl_tot_a[['시즌','홈팀','어웨이팀','경기결과','득점','실점','하프타임 득점 차','점유율','패스','터치','슈팅','유효슈팅','코너킥','태클','오프사이드','파울','엘로카드','레드카드']]
# Out:
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\sjh96\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
pl_tot_h['경기결과']=pl_tot_h['경기결과'].apply(home)
pl_tot_a['경기결과']=pl_tot_a['경기결과'].apply(away)
# Out:
# <ipython-input-17-317487a44b48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pl_tot_h['경기결과']=pl_tot_h['경기결과'].apply(home)

# %%
pl_Tot_no_son=pd.concat([pl_tot_h,pl_tot_a])
pl_Tot_no_son.sort_index(inplace=True)
pl_Tot_no_son
# Out:
#                시즌                    홈팀                     어웨이팀  경기결과  득점  \
# 날짜
# 2010-08-14  10/11     Tottenham Hotspur          Manchester City     1   0
# 2010-08-21  10/11            Stoke City        Tottenham Hotspur     3   2
# 2010-08-28  10/11     Tottenham Hotspur           Wigan Athletic     0   0
# 2010-09-11  10/11  West Bromwich Albion        Tottenham Hotspur     1   1
# 2010-09-18  10/11     Tottenham Hotspur  Wolverhampton Wanderers     3   3
# ...           ...                   ...                      ...   ...  ..
# 2015-04-25  14/15           Southampton        Tottenham Hotspur     1   2
# 2015-05-03  14/15     Tottenham Hotspur          Manchester City     0   0
# 2015-05-09  14/15            Stoke City        Tottenham Hotspur     0   0
# 2015-05-16  14/15     Tottenham Hotspur                Hull City     3   2
# 2015-05-24  14/15               Everton        Tottenham Hotspur     3   1
#
# ...

# %%
pl_Tot_no_son['득점'].mean()
# Out:
# 1.5789473684210527

# %%
pl_Tot_son['득점'].mean()
# Out:
# 1.8640350877192982

# %%
pl_Tot_no_son['경기결과'].mean()
# Out:
# 1.768421052631579

# %%
pl_Tot_son['경기결과'].mean()
# Out:
# 1.8640350877192982

# %%
pl_Tot_no_son['실점'].mean()
# Out:
# 1.2473684210526317

# %%
pl_Tot_son['실점'].mean()
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "C:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknow sysyem... sorry~')

# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
sns.heatmap(pl_Tot_no_son.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(pl_Tot_son.corr(),annot=True)
# Out:
# <AxesSubplot:>
